# %%
import pandas as pd 
df = pd.read_csv("HousingData.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# We need to check the null values
df = df.dropna()
df.isnull().sum()
# as there are no null values in the dataset we can move ahead
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
X = df.drop(columns = ["MEDV"])
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
y = df["MEDV"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
c
# Out:
# np.float64(30.05200114592282)

# %%
m = lr.coef_
m
# Out:
# array([-8.07259630e-02,  4.68425053e-02,  2.40956720e-02,  3.31677139e+00,
#        -2.00648622e+01,  4.82226270e+00, -2.88229632e-02, -1.55136726e+00,
#         2.38478176e-01, -1.23631969e-02, -8.74369727e-01,  9.29977915e-03,
#        -3.22635475e-01])

# %%
y_pred_train = lr.predict(X_train)
y_pred_train
# Out:
# array([33.25376523, 31.60217725, 25.47891705, 30.81037149, 21.84732099,
#        27.83869332, 30.48141494, 20.43612519, 22.48691871,  9.48438154,
#        11.49971611,  3.0214178 , 17.33874079, 23.72982168, 28.62484067,
#        14.63725484, 19.41968676, 32.73282833, 20.789186  , 32.47657636,
#        27.13916462, 28.47000746, 15.43841252, 14.9613839 ,  9.15746205,
#         3.62630228, 17.67110601, 16.57010218, 25.57887644, 20.65417819,
#        11.8432955 , 15.44298601, 16.83366988, 24.81926728, 23.77137568,
#        31.72610125, 25.56115496, 34.72218262, 43.26135542, 20.67784716,
#        24.44210008, 24.98822968, 26.40525165, 25.03724152, 18.4916525 ,
#        36.71658179, 25.44474643, 19.65967483, 24.63152872,  9.00494935,
#        32.58408462, 26.78418238, 23.00407315, 21.5471519 , 21.27129069,
#        22.3202995 ,  6.99191093, 14.45123818, 14.64293441, 16.88305187,
#        17.77178547, -2.05553283, 16.76258168, 17.35839363, 30.26510512,
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train, y_pred_train)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(y_train, y_pred_train) # (0 - 1)
# higher the r2 score, better the model is
# Out:
# 0.7927657852108867

# %%
# now we will test the data it has never seen the test data
y_pred_test = lr.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred_test)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.show()

# %%
r2 = r2_score(y_test, y_pred_test)
print("r2 Score : ", r2)
# Out:
# r2 Score :  0.6873411644615661

# %%
# The error should be as low as possible
from sklearn.metrics import mean_squared_error, mean_absolute_error
mse = mean_squared_error(y_test, y_pred_test)
mae = mean_absolute_error(y_test,y_pred_test)
print("Mean Square Error : ", mse)
print("Mean Absolute Error : ", mae)
# Out:
# Mean Square Error :  23.884522663593305
# Mean Absolute Error :  3.2710371885085965
